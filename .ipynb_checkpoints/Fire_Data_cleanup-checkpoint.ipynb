# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///Data/FPA_FOD_20170508.sqlite', echo=False)

# %%
fires_df = pd.read_sql(sql="Fires",con=engine,index_col='FOD_ID',columns=['FPA_ID','FIRE_NAME','FIRE_YEAR','DISCOVERY_DOY','DISCOVERY_TIME','STAT_CAUSE_DESCR','CONT_DOY','CONT_TIME','FIRE_SIZE','FIRE_SIZE_CLASS','LATITUDE','LONGITUDE','OWNER_CODE','OWNER_DESCR','STATE','COUNTY'])
fires_df.head()
# Out:
#             FPA_ID FIRE_NAME  FIRE_YEAR  DISCOVERY_DOY DISCOVERY_TIME  \
# FOD_ID
# 1       FS-1418826  FOUNTAIN       2005             33           1300
# 2       FS-1418827    PIGEON       2004            133           0845
# 3       FS-1418835     SLACK       2004            152           1921
# 4       FS-1418845      DEER       2004            180           1600
# 5       FS-1418847  STEVENOT       2004            180           1600
#
#        STAT_CAUSE_DESCR  CONT_DOY CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS  \
# FOD_ID
# 1         Miscellaneous      33.0      1730       0.10               A
# 2             Lightning     133.0      1530       0.25               A
# 3        Debris Burning     152.0      2024       0.10               A
# 4             Lightning     185.0      1400       0.10               A
# 5             Lightning     185.0      1200       0.10               A
#
#          LATITUDE   LONGITUDE  OWNER_CODE       OWNER_DESCR STATE COUNTY
# FOD_ID
# 1       40.036944 -121.005833         5.0              USFS    CA     63
# 2       38.933056 -120.404444         5.0              USFS    CA     61
# 3       38.984167 -120.735556        13.0  STATE OR PRIVATE    CA     17
# 4       38.559167 -119.913333         5.0              USFS    CA      3
# 5       38.559167 -119.933056         5.0              USFS    CA      3

# %%
fires_df.to_csv('Fire_Data.csv',index=False)
